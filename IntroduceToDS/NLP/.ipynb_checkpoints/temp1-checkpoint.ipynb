# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_table("Reviews.txt")
label = pd.read_csv("Labels.txt")
data
# Out:
#                                                 contents
# 0      bromwell high is a cartoon comedy . it ran at ...
# 1      story of a man who has unnatural feelings for ...
# 2      homelessness  or houselessness as george carli...
# 3      airport    starts as a brand new luxury    pla...
# 4      brilliant over  acting by lesley ann warren . ...
# 5      this film lacked something i couldn  t put my ...
# 6      this is easily the most underrated film inn th...
# 7      sorry everyone    i know this is supposed to b...
# 8      this is not the typical mel brooks film . it w...
# 9      when i was little my parents took me along to ...
# 10     this isn  t the comedic robin williams  nor is...
# 11     it appears that many critics find the idea of ...
# 12     yes its an art . . . to successfully make a sl...
# 13     the second attempt by a new york intellectual ...
# 14     in this  critically acclaimed psychological th...
# ...

# %%
data.describe()
# Out:
#                                                  contents
# count                                               20000
# unique                                              19926
# top     you do realize that you  ve been watching the ...
# freq                                                    3

# %%
label.loc[(label.label == 'positive'),'markers'] = 1 
label.loc[(label.label == 'negative'),'markers'] = 0
label.head(10)
# Out:
#    negative  positive
# 0         0         1
# 1         1         0
# 2         0         1
# 3         1         0
# 4         0         1
# 5         1         0
# 6         0         1
# 7         1         0
# 8         0         1
# 9         1         0

# %% [markdown]
# # 1文本预处理

# %% [markdown]
# ## 全部小写

# %%
data['contents'].str.lower()
# Out:
# 0        bromwell high is a cartoon comedy . it ran at ...
# 1        story of a man who has unnatural feelings for ...
# 2        homelessness  or houselessness as george carli...
# 3        airport    starts as a brand new luxury    pla...
# 4        brilliant over  acting by lesley ann warren . ...
# 5        this film lacked something i couldn  t put my ...
# 6        this is easily the most underrated film inn th...
# 7        sorry everyone    i know this is supposed to b...
# 8        this is not the typical mel brooks film . it w...
# 9        when i was little my parents took me along to ...
# 10       this isn  t the comedic robin williams  nor is...
# 11       it appears that many critics find the idea of ...
# 12       yes its an art . . . to successfully make a sl...
# 13       the second attempt by a new york intellectual ...
# 14       in this  critically acclaimed psychological th...
# 15       i don  t know who to blame  the timid writers ...
# ...

# %%
# Out:
#        positive  negative
# 0             1         0
# 1             1         0
# 2             1         0
# 3             1         0
# 4             1         0
# 5             1         0
# 6             1         0
# 7             1         0
# 8             1         0
# 9             1         0
# 10            1         0
# 11            1         0
# 12            1         0
# 13            1         0
# 14            1         0
# 15            1         0
# 16            1         0
# 17            1         0
# 18            1         0
# 19            1         0
# 20            1         0
# 21            1         0
# 22            1         0
# 23            1         0
# 24            1         0
# 25            1         0
# 26            1         0
# 27            1         0
# 28            1         0
# 29            1         0
# ...         ...       ...
# 19969         1         0
# 19970         1         0
# 19971         1         0
# ...
